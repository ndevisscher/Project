# %% [markdown]
# # Troonrede analyse
#
# Op het troonrede corpus kunnen we vergelijkbare analyses uitvoeren als gedaan op het State of teh Union corpus.
# Een heel gaaf onderzoek is <http://www.pnas.org/content/112/35/10837>, dat co-occurence (samen in een paragraaf) netwerken maakt van nouns en belangrijke bigrammen, en daar van alles mee doet.
#
# Dit is zeker ook herhaalbaar voor onze studenten op het troonrede corpus.
#
# Het "SI (Supplementary Material)" geeft ook genoeg informatie om eea te implementeren.

# %% [markdown]
# ## Data Science opdracht
#
# ### Deel 1 data preprocessing
# 1. Haal troonredes op van <http://www.troonredes.nl>
# 2. Haal de troonrede tekst uit de HTML files, en verbindt elke tekst met een jaartal.
#     * Wat doe je met de filenamen die geen jaartal zijn?
# 3. Parseer alle tekst mbv nltk of pattern
#     * Bewaar de paragraaf structuur.
#     * Maak bag of words
#     * Maak in ieder geval een data structuur  waarin je alleen de gelemmatisseerde zelfstandige naamwoorden overhoudt.
# 4. Sla je zo gemaakte data in een handig formaat op.
# 5. Maak wat mooie statistieken over je corpus:
#     * hoeveel termen, lengte per jaar, unieke woorden, etc etc.
#     * misschien wat mooie grafiekjes
#
# ### Deel 2 Netwerk van woorden
#
# 1. We maken het netwerk van zelfstandige naamwoorden zoals beschreven in het paper.
# 2. Gooi alle jaren bij elkaar.
# 3. Bereken de gewichten zoals beschreven in het SI.
#     * dus tel cooccurance
#     * bereken de pointwise MI
#     * gebruik hun formule
# 4. Maak een netwerk en verklein het zoals bescherevn in het artikel, totdat je een mooie verbonden component overhoudt.
# 5. Maak een functie die, net als in Figuur 1, het ego netwerk van een woord laat zien, maar dan zonder dat woord.
# 6. Doe clustering/community detectie, en probeer ook samenvattende labels voor je clusters te vinden, net als in het artikel.
# 7. Maak net zo'n gave tekening als in Figuur 3.
# 8. Evalueer je resultaten. Slaat het ergens op? Zijn die clusters echt woorden die bij elkaar horen?
#
#
# ### Deel 3 Cosine similarity
#
# 1. We maken hier Figuur 2 na.
# 2. Bereken de cosine similarity tussen alle troonredes.
# 3. Je kunt hier gaan experimenteren met
#     * het vocabulair (welke woorden neem je mee? Lemmas of "ruwe woorden")
#     * je weging van de woorden: ruwe tellingen, of misschien een versie van TF-IDF
# 4. Denk goed na hoe je cosine uitrekent.
#     * Een mooi voorbeeld is <http://blog.christianperone.com/2013/09/machine-learning-cosine-similarity-for-vector-space-models-part-iii/>
#     * Kijk ook naar <http://www.cs.duke.edu/courses/spring14/compsci290/assignments/lab02.html> om te zien hoe je een lijst met tokens als input voor scikit learn's TFIDF vectorizer kunt geven.
#
# 5. Maak net zo'n mooie print als Figuur 2.
# 6. Kan je vergelijkbare "scheidingen tussen periodes" ontdekken?
#
# ### Deel 4 Clusters door de tijd
# 1. Je maakt Figuur 4 na.

# %% [markdown]
# # Putting the troonredes into text
#
# ## Step 1
# * copying them into files with the year of the troonrede as filename.

# %%
# Putting the troonredes into text

#!tar xfz troonredes.tar
#! mkdir troonredes
! for f in www.troonredes.nl/troonrede-*; do g=`echo $f|sed 's/.*[a-z]-//'`; cp $f/index.html "troonredes/$g.html";done

# %%
# !ls troonredes/
# Out:
# 1818.html   1831.html   1844.html   1876.html   1892.html   1925.html   1937.html   1959.html   1979.html   2001.html   2013.html
# 1820.html   1832.html   1845.html   1877.html   1893.html   1926.html   1938.html   1960.html   1980.html   2002.html   2014.html
# 1821.html   1833.html   1846.html   1878.html   1894.html   1927.html   1939.html   1961.html   1981.html   2003.html
# 1822.html   1834.html   1847.html   1879.html   1895.html   1928.html   1946-2.html 1962.html   1982.html   2004.html
# 1823.html   1835.html   1848.html   1880.html   1896.html   1929.html   1946.html   1963.html   1983.html   2005.html
# 1824.html   1836.html   1849.html   1882.html   1897.html   1930.html   1948-2.html 1964.html   1984.html   2006.html
# 1825.html   1838.html   1870.html   1883.html   1898.html   1931.html   1949-2.html 1965.html   1985.html   2007.html
# 1826.html   1839.html   1871.html   1884.html   1899.html   1932.html   1954.html   1966.html   1986.html   2008.html
# 1827.html   1840.html   1872.html   1885.html   1900.html   1933.html   1955.html   1967.html   1987.html   2009.html
# 1828.html   1841.html   1873.html   1886.html   1904.html   1934.html   1956.html   1976-2.html 1988.html   2010.html
# 1829.html   1842.html   1874.html   1887.html   1923-2.html 1935.html   1957.html   1976.html   1989.html   2011.html
# 1830.html   1843.html   1875.html   1891.html   1923.html   1936.html   1958.html   1978.html   2000.html   2012.html

# %%
# !rm -r www.troonredes.nl/

# %% [markdown]
# ## step 2 parse a document
#
# * extract the paragraphs with Beautifulsoup
# * Parse each paragraph with pattern into sentences and store lemmata

# %%
from bs4 import BeautifulSoup
from pattern.nl import parsetree, pprint
# the tekst is in <div id="post-content">

f= open('troonredes/1818.html').read()
soup= BeautifulSoup(f)

ourdiv=soup.find('div', id="post-content") 
 
ourpars= [parsetree(p.text, lemmata=True, Relations=True) for p in ourdiv.findAll('p')]

# %%
# number of sentences 
sum(len(p) for p in ourpars)
# Out:
# 46

# %% [markdown]
# ## Step 3 for all documents
#
# * We create two dicts with the years as keys and the troonredes represented as lists of paragraphs as values
#     * parsedtroonredes  (all information)
#     * Nounstroonredes (each paragraph contains the set of lemmatized nons in that paragraph)

# %%
import glob



# this does just what we tried out in step 2
def parse_troonrede(f):
    '''Read a troonrede file, extract all text and output a list of lists, 
    each element is a paragraph containing a list of sentences,
    each sentence is parsed.'''
    soup= BeautifulSoup(open(f).read())
    ourdiv=soup.find('div', id="post-content") 
    ourpars= [parsetree(p.text, lemmata=True, Relations=True) for p in ourdiv.findAll('p')]
    return ourpars

# test
#parse_troonrede('troonredes/1818.html')



# this applies step 2 to all troonredes 
def parse_corpus(folder):
    alltroonredes= glob.glob(folder)
    troonredes={}
    for troonrede in alltroonredes:
        key= troonrede.split('/')[1].replace('.html','')
        value= parse_troonrede(troonrede)
        troonredes[key]=value
    return troonredes


# %time parsedtroonredes= parse_corpus('troonredes/*.html')
# Out:
# CPU times: user 49 s, sys: 849 ms, total: 49.8 s
# Wall time: 52.7 s

# %%
# We only want to keep the lemmatized nouns and group them by paragraaf

def reduce_to_nouns(parsedcorpus):
    nouns_coocuuring_per_paragraph= [list(set([ w.lemma for s in p for w in s.nouns]))  for p in parsedcorpus  ]
    return nouns_coocuuring_per_paragraph

# %time Nounstroonredes= {k:reduce_to_nouns(parsedtroonredes[k]) for k in parsedtroonredes}
# Out:
# CPU times: user 159 ms, sys: 31.2 ms, total: 191 ms
# Wall time: 172 ms

# %%
Nounstroonredes['2000']
# Out:
# [[u'staten-generaal', u'leed'],
#  [u'begin',
#   u'land',
#   u'welvaart',
#   u'staat',
#   u'ons\xa0land',
#   u'uitdaging',
#   u'investering',
#   u'welzijn',
#   u'structuur',
#   u'eeuw',
#   u'periode',
#   u'samenleving',
#   u'antwoord',
#   u'voorspoed'],
#  [u'infrastructuur',
#   u'jaar',
#   u'leefbaarheid',
#   u'gulden',
#   u'situatie',
#   u'regering',
#   u'overheidstaak',
#   u'onderwijs',
#   u'milieu',
#   u'regeerakkoord',
#   u'middeel',
#   u'onderzoek',
#   u'natuur',
#   u'veiligheid',
#   u'ruimte',
#   u'bedrag',
#   u'verdubbeling',
#   u'gezondheidszorg'],
#  [u'samenstelling',
#   u'ontwikkeling',
#   u'nederland',
#   u'decennia',
#   u'invloed',
#   u'internationalisering',
#   u'bevolking',
#   u'individualisering'],
#  [u'eis',
#   u'voorziening',
#   u'overheid',
#   u'maatschappij',
#   u'beschikbaarheid',
#   u'rekening',
#   u'keuzevrijheid',
#   u'kwaliteit',
#   u'behoefte'],
#  [u'eis',
#   u'arbeid',
#   u'concurrentiekracht',
#   u'welvaart',
#   u'nederland',
#   u'basis',
#   u'fiscaal',
#   u'stelsel',
#   u'vergroot',
#   u'lastenverlichting',
#   u'bevordert',
#   u'invoering',
#   u'robuust',
#   u'januari',
#   u'ontwikkeling',
#   u'tijd'],
#  [u'aow-spaarfonds',
#   u'jaar',
#   u'daling',
#   u'ouderenpensioen',
#   u'generatie',
#   u'decennia',
#   u'doel',
#   u'solidariteit',
#   u'samenleving',
#   u'toekomst',
#   u'opbouw'],
#  [u'jaar', u'economie'],
#  [u'toename',
#   u'vacature',
#   u'mens',
#   u'redeen',
#   u'\xe9n',
#   u'werk',
#   u'arbeidsparticipatie',
#   u'werkgelegenheid',
#   u'aantal'],
#  [u'werkzoekend', u'regering', u'deelname', u'arbeid'],
#  [u'sector',
#   u'verantwoordelijkheid',
#   u'onderwijs',
#   u'knelpunt',
#   u'overheid',
#   u'taak',
#   u'arbeidskracht',
#   u'tekort',
#   u'uitvoering',
#   u'regering',
#   u'gezondheidszorg'],
#  [u'wao',
#   u'regering',
#   u'beroep',
#   u're\xefntegratie',
#   u'uitvoeringsorganisatie',
#   u'arbeidsvoorziening',
#   u'mens',
#   u'zekerheid',
#   u'preventie'],
#  [u'zelfstandigheid',
#   u'naast',
#   u'regering',
#   u'vrouw',
#   u'vergroot',
#   u'mens',
#   u'zorg',
#   u'ouderschapsverlof',
#   u'balan',
#   u'keuzevrijheid',
#   u'werk',
#   u'man',
#   u'behoefte',
#   u'fiscaal',
#   u'mogelijkheid',
#   u'priv\xe9leef'],
#  [u'kinderopvang', u'opvang', u'schooltijd', u'mogelijkheid'],
#  [u'vrijwilliger',
#   u'arbeidssituatie',
#   u'rol',
#   u'levert',
#   u'van\xa0vel',
#   u'bijdrage',
#   u'inzet',
#   u'welzijn',
#   u'burger',
#   u'samenleving',
#   u'vervul'],
#  [u'eis',
#   u'talent',
#   u'afspraak',
#   u'kennis',
#   u'uitgaf',
#   u'onderwijs',
#   u'jaar',
#   u'mens',
#   u'unie',
#   u'vaardigheid',
#   u'onderzoek',
#   u'aansluiting',
#   u'maatschappij',
#   u'vernieuwing',
#   u'kans'],
#  [u'',
#   u'kind',
#   u'verwerving',
#   u'achterstand',
#   u'school',
#   u'kennis',
#   u'leeftijd',
#   u'taalprogramma',
#   u'doorstroming',
#   u'onderwijs',
#   u'jaar',
#   u'schaal',
#   u'leer\u2013',
#   u'vaardigheid',
#   u'vraag',
#   u'vervolgonderwijs',
#   u'gemeent',
#   u'fundament',
#   u'\u2019'],
#  [u'school',
#   u'computer',
#   u'invoering',
#   u'kennis',
#   u'basis',
#   u'regering',
#   u'toepassing',
#   u'onderwijs',
#   u'verdieping',
#   u'kennisnet',
#   u'innovatie',
#   u'middeel',
#   u'onderzoek',
#   u'vorm',
#   u'samenleving',
#   u'aansluiting'],
#  [u'jeugd',
#   u'aansluiting',
#   u'ontwikkeling',
#   u'leven',
#   u'aandacht',
#   u'overheid',
#   u'informatie\u2013',
#   u'tempo',
#   u'burger',
#   u'invloed',
#   u'computer',
#   u'communicatietechnologie',
#   u'samenleving',
#   u'sciencefiction',
#   u'ware',
#   u'mogelijkheid'],
#  [u'oog',
#   u'welvaart',
#   u'burger',
#   u'belang',
#   u'bijdrage',
#   u'toegankelijkheid',
#   u'kwaliteit',
#   u'cultuur',
#   u'samenleving',
#   u'betekenis',
#   u'kunst'],
#  [u'broeikasgas',
#   u'ontwikkeling',
#   u'welvaart',
#   u'klimaatverandering',
#   u'wetenschap',
#   u'milieudruk',
#   u'gebruik',
#   u'energiegebruik',
#   u'duurzame',
#   u'wereldwijde',
#   u'innovatie',
#   u'afspraak',
#   u'energie',
#   u'regering',
#   u'bron',
#   u'uitstoot',
#   u'technologie',
#   u'mogelijkheid',
#   u'maatregel'],
#  [u'landbouwmethood',
#   u'jaar',
#   u'duurzame',
#   u'bedrijfsvoering',
#   u'toepassing',
#   u'milieuprobleem',
#   u'aanpas',
#   u'veehouderij',
#   u'vernieuwing',
#   u'landbouw',
#   u'maatregel'],
#  [u'voorwaard',
#   u'verdeling',
#   u'mens',
#   u'schep',
#   u'economie',
#   u'ruimte',
#   u'woonomgeving',
#   u'keus'],
#  [u'opslag',
#   u'rivier',
#   u'aandacht',
#   u'landschap',
#   u'leefomgeving',
#   u'oog',
#   u'waterkwaliteit',
#   u'westen',
#   u'water',
#   u'waterbeheer',
#   u'land',
#   u'natuur',
#   u'bodemdaling',
#   u'oplossing',
#   u'peil',
#   u'opdracht'],
#  [u'expansie',
#   u'toename',
#   u'land',
#   u'bereikbaarheid',
#   u'maatregel',
#   u'recente',
#   u'invulling',
#   u'belang',
#   u'mobiliteit',
#   u'randstad',
#   u'wijze',
#   u'deel',
#   u'afspraak',
#   u'presenteer',
#   u'regering',
#   u'termijn',
#   u'noodzaak',
#   u'behoeft',
#   u'emancipatie'],
#  [u'jaar',
#   u'woonomgeving',
#   u'regering',
#   u'burger',
#   u'stad',
#   u'afspraak',
#   u'verbetering',
#   u'vitaal'],
#  [u'regelgeving',
#   u'vuurwerkramp',
#   u'herstel',
#   u'voorbereiding',
#   u'inzet',
#   u'gebeurtenis',
#   u'schade',
#   u'veiligheid',
#   u'wederopbouw',
#   u'woonomgeving',
#   u'enschede'],
#  [u'verantwoordelijkheid',
#   u'handhaving',
#   u'overheid',
#   u'toezien',
#   u'uitvoering',
#   u'burger',
#   u'regel',
#   u'en\xa0neem',
#   u'bedrijf',
#   u'samenleving',
#   u'organisatie',
#   u'norm'],
#  [u'jeugdcriminaliteit',
#   u'periode',
#   u'samenwerking',
#   u'aandacht',
#   u'misdaad',
#   u'overheid',
#   u'mensensmokkel',
#   u'inzet',
#   u'criminaliteit',
#   u'straat',
#   u'verkeersveiligheid',
#   u'geweld',
#   u'veiligheid',
#   u'bestrijd',
#   u'milieudelict'],
#  [u'opsporing',
#   u'inbegrip',
#   u'misdrijf',
#   u'afweging',
#   u'techniek',
#   u'dna-onderzoek',
#   u'effectiviteit',
#   u'levenssfeer'],
#  [u'rechtspraak',
#   u'levert',
#   u'regering',
#   u'modernisering',
#   u'snelheid',
#   u'kwaliteit',
#   u'inspanning',
#   u'behandeling'],
#  [u'sluitstuk', u'strafrechtkeet', u'stelsel', u'regering'],
#  [u'toelatingsbeleid',
#   u'asiel\u2013',
#   u'regering',
#   u'invulling',
#   u'doel',
#   u'afspraak',
#   u'vreemdelingenwet',
#   u'verkorten',
#   u'helft',
#   u'wet',
#   u'restrictief',
#   u'migratiebeleid',
#   u'asielprocedure'],
#  [u'nederlander',
#   u'stap',
#   u'opstelling',
#   u'regering',
#   u'taal',
#   u'integratieproces',
#   u'migrant',
#   u'samenleving',
#   u'inburgeringscursus',
#   u'leidraad',
#   u'betekenis',
#   u'betrokkeen',
#   u'inburgering',
#   u'te\xa0zijn',
#   u'respect',
#   u'behoort'],
#  [u'gevolg',
#   u'jaar',
#   u'voorziening',
#   u'wachttijd',
#   u'regering',
#   u'beroep',
#   u'zorg',
#   u'middeel',
#   u'capaciteit'],
#  [u'toename',
#   u'systeem',
#   u'ontwikkeling',
#   u'aantal',
#   u'regering',
#   u'peil',
#   u'vernieuwing',
#   u'stelsel',
#   u'zorg',
#   u'steeds',
#   u'technologische',
#   u'aanpassing',
#   u'zorgverzekering',
#   u'organisatie',
#   u'tijd',
#   u'behoefte',
#   u'financiering',
#   u'gezondheidszorg'],
#  [u'',
#   u'embryo',
#   u'modificatie',
#   u'ontwikkeling',
#   u'geneeskunde',
#   u'voorbeeld',
#   u'acht',
#   u'voedselproductie',
#   u'ontrafeling',
#   u'ziekt',
#   u'gedacht',
#   u'doeleind',
#   u'verbetering',
#   u'regering',
#   u'\u2019',
#   u'dilemma',
#   u'genoom',
#   u'genezing',
#   u'parlement',
#   u'onderzoek'],
#  [u'grondwet',
#   u'onderwerp',
#   u'aantal',
#   u'regering',
#   u'referendum',
#   u'verandering',
#   u'samenleving',
#   u'document',
#   u'correctief',
#   u'plaats'],
#  [u'jaar',
#   u'herkenbaarheid',
#   u'taakverdeling',
#   u'regering',
#   u'bestuur',
#   u'democratie',
#   u'lokaal'],
#  [u'beheersing',
#   u'antillen',
#   u'perspectief',
#   u'herstel',
#   u'nederland',
#   u'samenwerking',
#   u'urgentieprogramma',
#   u'regering',
#   u'ontwikkeling',
#   u'overheidsuitgaf',
#   u'kwaliteit',
#   u'openbaar',
#   u'hand',
#   u'uitvoering',
#   u'aandacht',
#   u'aruba',
#   u'nederlands-antilliaanse',
#   u'duurzaam',
#   u'toekomst',
#   u'bestuur'],
#  [u'geld',
#   u'jaar',
#   u'europa',
#   u'samenwerking',
#   u'burger',
#   u'gulden',
#   u'totstandkoming',
#   u'unie',
#   u'monetaire',
#   u'proces',
#   u'munteenheid',
#   u'economische',
#   u'toekomst',
#   u'n\xf3g',
#   u'buitenland',
#   u'kans',
#   u'euro'],
#  [u'',
#   u'inhoud',
#   u'europa',
#   u'duurzame',
#   u'niveau',
#   u'vredesoperatie',
#   u'crisisbeheersings\u2013',
#   u'doel',
#   u'groei',
#   u'bijdrage',
#   u'unie',
#   u'samenhang',
#   u'regio',
#   u'\u2019',
#   u'verantwoordelijkheid',
#   u'werkgelegenheid',
#   u'wereld'],
#  [u'land',
#   u'ondersteunt',
#   u'nederland',
#   u'democratie',
#   u'oost-europa',
#   u'voorbereiding',
#   u'midden\u2013',
#   u'stabiliteit',
#   u'verankert',
#   u'inspanning',
#   u'lidmaatschap',
#   u'lidstaat',
#   u'unie',
#   u'uitbreiding',
#   u'continent',
#   u'kans',
#   u'kandidaat-leed',
#   u'opdracht'],
#  [u'onderwerp',
#   u'aantal',
#   u'nederland',
#   u'samenwerking',
#   u'eenheid',
#   u'vooruitzicht',
#   u'unieverdrag',
#   u'verdragswijziging',
#   u'lidstaat',
#   u'ruimte',
#   u'unie',
#   u'legitimiteit',
#   u'slagvaardigheid',
#   u'stem',
#   u'eenparigheid'],
#  [u'ontwikkelingsland',
#   u'uitzicht',
#   u'ingezet',
#   u'beleid',
#   u'ontwikkelingssamenwerking',
#   u'waardigheid',
#   u'deelname',
#   u'wereldhandelsstelsel',
#   u'globalisering',
#   u'centraal',
#   u'welzijn',
#   u'vrede',
#   u'wereldwijde',
#   u'middeel',
#   u'vooruitgang',
#   u'vrucht',
#   u'veiligheid',
#   u'bestuur',
#   u'armoede',
#   u'multilateraal',
#   u'gebruik'],
#  [u'naties',
#   u'teisteer',
#   u'maand',
#   u'rol',
#   u'verantwoordelijkheid',
#   u'top',
#   u'wereldorde',
#   u'ideaal',
#   u'millennium',
#   u'verenigde',
#   u'grondslag',
#   u'afrikaanse',
#   u'gemeenschap',
#   u'continent',
#   u'conflict'],
#  [u'vooravond',
#   u'jaar',
#   u'viering',
#   u'regering',
#   u'rechtsstaat',
#   u'suriname',
#   u'probleem',
#   u'onafhankelijkheid'],
#  [u'nederland',
#   u'samenwerking',
#   u'regering',
#   u'invulling',
#   u'positief',
#   u'nauwer',
#   u'programma',
#   u'wens'],
#  [u'levert',
#   u'personeel',
#   u'navo',
#   u'inzet',
#   u'band',
#   u'steun',
#   u'middeel',
#   u'bijdrage',
#   u'krijgsmacht',
#   u'vredesoperatie',
#   u'wederopbouw',
#   u'veiligheidsbeleid',
#   u'hulp'],
#  [u'waardering', u'bijdraag', u'inzet'],
#  [u'staten-generaal', u'leed'],
#  [u'jaar', u'toekomst', u'voorspoed', u'vorm', u'mogelijkheid'],
#  [u'perspectief',
#   u'cohesie',
#   u'regering',
#   u'taak',
#   u'volksvertegenwoordiging',
#   u'fundament',
#   u'samenleving',
#   u'duurzaam',
#   u'toekomst',
#   u'plaats',
#   u'opdracht'],
#  [u'toewens',
#   u'wijsheid',
#   u'taak',
#   u'inzet',
#   u'zeeg',
#   u'toewijding',
#   u'harte',
#   u'wens']]

# %%
# A few stats

def NrWords(L):
    terms=[]
    for p in L:
        terms+=p
    return(len(terms),len(set(terms)))


# test
# NrWords(Nounstroonredes['2000'])

Nrwords= {y:NrWords(Nounstroonredes[y]) for y in Nounstroonredes}

def Vocabulary(Dict):
    terms=[]
    for y in Dict:
        for p in Dict[y]:
            terms+=p
    return Counter(terms)

TroonredeNounsVocab=Vocabulary(Nounstroonredes)

# %% [markdown]
# # some stats on the whole corpus

# %%
# some stats on the whole corpus

# number of unique nouns, number of non-hapaxes, total number of nouns, top 20 nouns

(len(TroonredeNounsVocab), 
 len([t for t in TroonredeNounsVocab if TroonredeNounsVocab[t] >1]),
 sum(TroonredeNounsVocab.values()), 
 TroonredeNounsVocab.most_common(20)
 )
# Out:
# (6593,
#  3212,
#  39671,
#  [(u'regering', 622),
#   (u'jaar', 486),
#   (u'den', 481),
#   (u'land', 344),
#   (u'staten-generaal', 245),
#   (u'maatregel', 229),
#   (u'nederland', 229),
#   (u'ontwikkeling', 226),
#   (u'belang', 220),
#   (u'aandacht', 200),
#   (u'zitting', 175),
#   (u'wet', 172),
#   (u'zorg', 167),
#   (u'verbetering', 164),
#   (u'toestand', 160),
#   (u'beleid', 160),
#   (u'edel', 160),
#   (u'samenwerking', 152),
#   (u'middeel', 139),
#   (u'onderwijs', 139)])

# %% [markdown]
# # Compute co occurance

# %%
# Compute co occurance

from collections import defaultdict, Counter

def pars2cooccurance(L):
    '''L is a list of lists of terms. We output a Counter object with alphabetically 
    ordered pairs of terms as keys and the number of times they co
    occur as values.'''
    pairs = [ t1+'-'+t2 for list in L for t1 in list for t2 in list if t1 < t2]
    return Counter(pairs)

#test

#pars2cooccurance(Nounstroonredes['2000']).most_common(10)

% time coOccuringNouns= {y:pars2cooccurance(Nounstroonredes[y]) for y in Nounstroonredes}

# test
#coOccuringNouns['2000'].most_common(10)
# Out:
# CPU times: user 410 ms, sys: 81.8 ms, total: 492 ms
# Wall time: 456 ms
# [(u'jaar-regering', 5),
#  (u'burger-samenleving', 4),
#  (u'ontwikkeling-regering', 4),
#  (u'afspraak-regering', 4),
#  (u'regering-samenleving', 4),
#  (u'jaar-onderwijs', 3),
#  (u'jaar-toekomst', 3),
#  (u'gezondheidszorg-regering', 3),
#  (u'kans-unie', 3),
#  (u'middeel-regering', 3)]

# %% [markdown]
# ## Network of nouns
#
# * See the [Suppplementary material](http://www.pnas.org/content/suppl/2015/08/06/1512221112.DCSupplemental/pnas.201512221SI.pdf) for how the weights were detremined from the raw cooccurence scores.
# * Then they removed nodes keeping only a (weakly) connected component, with a few nouns left.
# * Then they ran the Louvain community detection algorithm on the resulting connected network.
#     * It is not clear from the SI whether they simply made all directed edges undirected.
#
# #### Hints
# * See <http://www.inf.ed.ac.uk/teaching/courses/fnlp/Tutorials/5_MI/lab5.pdf> how to compute the pointwise mutual information scores using NLTK.
# * But we can also do this simply ourselves of course using our Counters.
#
# #### Start
# * Start with removing all years and adding all terms  and pairs to one big heap of terms.

# %%
import nltk

# %%
nltk.probability.MLEProbDist?
